# %% [markdown]
# # Import library

# %%
import pandas as pd

# %% [markdown]
# # Read the Dataset

# %%
movies=pd.read_csv(r"C:\Users\LENOVO\Downloads\PYTHON-CHAPTER-1\movie.csv")

# %%
movies.shape
# Out:
# (27278, 3)

# %%
ratings=pd.read_csv(r"C:\Users\LENOVO\Downloads\PYTHON-CHAPTER-1\rating.csv")

# %%
ratings.shape
# Out:
# (20000263, 4)

# %%
tags=pd.read_csv(r"C:\Users\LENOVO\Downloads\PYTHON-CHAPTER-1\tag.csv")

# %%
tags.shape
# Out:
# (465564, 4)

# %% [markdown]
# # Data analysis

# %%
print(movies.columns)
print(tags.columns)
print(ratings.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='str')
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='str')
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='str')

# %% [markdown]
# # for Current analysis , we will remove timestamp

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
print(movies.columns)
print(tags.columns)
print(ratings.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='str')
# Index(['userId', 'movieId', 'tag'], dtype='str')
# Index(['userId', 'movieId', 'rating'], dtype='str')

# %% [markdown]
# # Data structures:

# %%
tags.head(2)
# Out:
#    userId  movieId          tag
# 0      18     4141  Mark Waters
# 1      65      208    dark hero

# %%
row_0=tags.iloc[0]   #integer location
row_0
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
row_0=tags.iloc[1]   
row_0
# Out:
# userId            65
# movieId          208
# tag        dark hero
# Name: 1, dtype: object

# %%
row_0['userId']
# Out:
# np.int64(65)

# %%
'rating' in row_0
# Out:
# False

# %%
row_0.name
# Out:
# 1

# %%
row_0 = row_0.rename('firstRow')
row_0.name
# Out:
# 'firstRow'

# %% [markdown]
# # DataFrames

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='str')

# %%
tags.iloc[ [0,11,500] ]
# Out:
#      userId  movieId                tag
# 0        18     4141        Mark Waters
# 11       65     1783      noir thriller
# 500     342    55908  entirely dialogue

# %% [markdown]
# #  Descriptive Statistics

# %%
ratings['rating'].describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings.describe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00

# %%
ratings['rating'].mean()
# Out:
# np.float64(3.5255285642993797)

# %%
ratings.mean()
# Out:
# userId     69045.872583
# movieId     9041.567330
# rating         3.525529
# dtype: float64

# %%
ratings['rating'].min()
# Out:
# np.float64(0.5)

# %%
ratings['rating'].max()
# Out:
# np.float64(5.0)

# %%
ratings['rating'].std()
# Out:
# np.float64(1.0519889192942418)

# %%
ratings['rating'].mode()
# Out:
# 0    4.0
# Name: rating, dtype: float64

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.000850  0.001175
# movieId -0.000850  1.000000  0.002606
# rating   0.001175  0.002606  1.000000

# %%
filter1 = ratings['rating'] > 10
print(filter1)
filter1.any()
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258    False
# 20000259    False
# 20000260    False
# 20000261    False
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool
# np.False_

# %%
filter2 = ratings['rating'] > 0
filter2.all()
# Out:
# np.True_

# %% [markdown]
# # Data Cleaning: Handling Missing Data

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.isnull().any().any()
# Out:
# np.False_

# %%
ratings.shape
# Out:
# (20000263, 3)

# %%
ratings.isnull().any().any()
# Out:
# np.False_

# %%
tags.shape
# Out:
# (465564, 3)

# %%
tags.isnull().any().any()
# Out:
# np.True_

# %%
tags=tags.dropna()

# %%
tags.isnull().any().any()
# Out:
# np.False_

# %%
tags.shape
# Out:
# (465548, 3)

# %% [markdown]
# # Data Visualization

# %%
# %matplotlib inline

ratings.hist(column='rating', figsize=(10,5))
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
ratings.boxplot(column='rating', figsize=(10,5))
# Out:
# <Axes: >

# %% [markdown]
# #  Slicing Out Columns

# %%
tags['tag'].head()
# Out:
# 0      Mark Waters
# 1        dark hero
# 2        dark hero
# 3    noir thriller
# 4        dark hero
# Name: tag, dtype: str

# %%
movies[['title','genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings[-10:]
# Out:
#           userId  movieId  rating
# 20000253  138493    60816     4.5
# 20000254  138493    61160     4.0
# 20000255  138493    65682     4.5
# 20000256  138493    66762     4.5
# 20000257  138493    68319     4.5
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5

# %%
tag_counts = tags['tag'].value_counts()
tag_counts[-10:]
# Out:
# tag
# Roland Joff̩                                                           1
# Seu Jorge                                                               1
# Michel Audiard                                                          1
# French film                                                             1
# Clouseau                                                                1
# Disguises                                                               1
# retarted                                                                1
# circle k                                                                1
# This movie should have been called \\"How Cocaine Ruined Disney\"\""    1
# topless scene                                                           1
# Name: count, dtype: int64

# %%
tag_counts[:10].plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='tag'>
