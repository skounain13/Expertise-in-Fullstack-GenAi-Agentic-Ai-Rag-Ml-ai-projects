# %% [markdown]
# # 1)VARIABLE NO NEED TO HAVE ()

# %%
10+5
# Out:
# 15

# %% [markdown]
# # 2)VARIABLE IS THE NAME GIVEN TO THE MEMORY LOCATION IN PROGRAM HERE 'a' IS A VARIABLE (OR) OBJECT,WHERE AS 5 IS A VALUE (OR) DATATYPE

# %%
a=5
a
# Out:
# 5

# %%
b=2
b
# Out:
# 2

# %% [markdown]
# # here it stores the output of previous memory

# %%
_+3
# Out:
# 5

# %% [markdown]
# # 3)PYTHON IS A CASE SENSITIVE,it is valid when strating character is in upper case except for From,True,None

# %%
jghj=7
jghj
# Out:
# 7

# %%
high=5
HIGH
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 high=5
# ----> 2 HIGH
#
# NameError: name 'HIGH' is not defined

# %%
EFGH=5
EFGH
# Out:
# 5

# %% [markdown]
# # 3)THERE SHOULD NOT BE NO. AT STARTING ,BUT ALWAYS ENDS WITH NUMBER

# %%
1a=2
1a
# Out:
#   Cell In[8], line 1
#     1a=2
#     ^
# SyntaxError: invalid decimal literal

# %%
a1=2
a1
# Out:
# 2

# %%
a123=5
a123
# Out:
# 5

# %% [markdown]
# # 4)WE CANT USE SPEACIAL CHAR OTHER THAN '_'

# %%
a@=2
a@
# Out:
#   Cell In[11], line 2
#     a@
#       ^
# SyntaxError: invalid syntax

# %%
a_=3
a_
# Out:
# 3

# %%
_d=10
_d
# Out:
# 10

# %% [markdown]
# # HERE IS STORES PREVIOUS OUTPUT IN MEMORY

# %%
_+15
# Out:
# 25

# %% [markdown]
# # 5)THERE ARE KEYWORDS IN PYTHON,AND CAN'T BE USED AS VARIABLE

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
from=5
from
# Out:
#   Cell In[17], line 1
#     from=5
#         ^
# SyntaxError: invalid syntax

# %%
From=5
From
# Out:
# 5

# %%
True=5
# Out:
#   Cell In[19], line 1
#     True=5
#     ^
# SyntaxError: cannot assign to True

# %%
true=5
