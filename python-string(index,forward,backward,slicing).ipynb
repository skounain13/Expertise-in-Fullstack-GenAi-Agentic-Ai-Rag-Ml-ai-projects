# %% [markdown]
# # 1.Strings(one line sentence)

# %%
s1=welcome
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 s1=welcome
#
# NameError: name 'welcome' is not defined

# %%
s1='welcome
# Out:
#   Cell In[2], line 1
#     s1='welcome
#        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s1="welcome"
s1
# Out:
# 'welcome'

# %%
s1="welcome to sumayya kounain"
s1
# Out:
# 'welcome to sumayya kounain'

# %% [markdown]
# # 2)string with paragraph

# %%
s1="welcome
    to
    sumayya kounain
    practice
    session"
s1
# Out:
#   Cell In[12], line 1
#     s1="welcome
#        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s1='welcome
    to
    sumayya kounain
    practice
    session'
s1
# Out:
#   Cell In[13], line 1
#     s1='welcome
#        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s1='''welcome
    to
    sumayya kounain
    practice
    session'''
s1
# Out:
# 'welcome\n    to\n    sumayya kounain\n    practice\n    session'

# %%
s1="""welcome
    to
    sumayya kounain
    practice
    session"""
s1
# Out:
# 'welcome\n    to\n    sumayya kounain\n    practice\n    session'

# %% [markdown]
# # 3)Indexing(Forward,Backward)

# %% [raw]
# # i)forward indexing starts from 0(left to right)

# %%
s2="welcome"
s2
# Out:
# 'welcome'

# %%
s2[0]
# Out:
# 'w'

# %%
s2[1]
# Out:
# 'e'

# %%
s2[2]
# Out:
# 'l'

# %%
s2[3]
# Out:
# 'c'

# %%
s2[6]
# Out:
# 'e'

# %%
s2[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 s2[7]
#
# IndexError: string index out of range

# %%
s2[]
# Out:
#   Cell In[24], line 1
#     s2[]
#        ^
# SyntaxError: invalid syntax

# %% [raw]
# # ii)Backward index starts from -1(right to left)

# %%
s2[-1]
# Out:
# 'e'

# %%
s2[-2]
# Out:
# 'm'

# %%
s2[-7]
# Out:
# 'w'

# %%
s2[-8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 s2[-8]
#
# IndexError: string index out of range

# %% [markdown]
# # 4)slicing(forward,backward,advance,step)

# %% [raw]
# # i)forward slicing

# %%
s2[0:7]
# Out:
# 'welcome'

# %%
s2[0:6]
# Out:
# 'welcom'

# %%
s2[:]
# Out:
# 'welcome'

# %%
s2[:7]
# Out:
# 'welcome'

# %%
s2[0:7]
# Out:
# 'welcome'

# %%
s2[3:10]
# Out:
# 'come'

# %%
s2[2:]
# Out:
# 'lcome'

# %%
s2[::2]
# Out:
# 'wloe'

# %%
s2[::5]
# Out:
# 'wm'

# %% [raw]
# # ii)Backward slicing

# %%
s2[-5:-1]
# Out:
# 'lcom'

# %%
s2[-7:-1]
# Out:
# 'welcom'

# %%
s2[-8:-1]
# Out:
# 'welcom'

# %%
s2[::-1]
# Out:
# 'emoclew'

# %%
s2[::-2]
# Out:
# 'eolw'

# %%
s2[::-7]
# Out:
# 'e'

# %%
s2[::-6]
# Out:
# 'ew'

# %%
s2[::]
# Out:
# 'welcome'
