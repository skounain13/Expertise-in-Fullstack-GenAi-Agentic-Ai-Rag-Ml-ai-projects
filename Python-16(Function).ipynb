# %%
def greet():
    print("Good Morning")

# %%
def greet(): #difining the function
    print("Good Morning")
greet()    #calling the function
# Out:
# Good Morning

# %%
class wish():
    def greet():      # any function inside a class becomes a method in oops concept  ,here greet is a method
        print("good bye")
    greet()
# Out:
# good bye

# %%
def greet(): #no indentation error
print("Good Morning")
greet()
# Out:
#   Cell In[7], line 2
#     print("Good Morning")
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
def greet(): #one indentation is enough
 print("Good Morning")
greet()
# Out:
# Good Morning

# %%
def greet(): #difining the function
    print("Good Morning")
greet()
def greet():
    print("Good Morning")
greet()
# Out:
# Good Morning
# Good Evening

# %%
def greet(): #difining the function
    print("Good Morning")
greet()
def greet():
    print("Good Morning")
greet()
def greet():
    print("Good Morning")
greet()
# Out:
# Good Morning
# Good Morning
# Good Morning

# %%
def greet():  # you define the statement once you can call as many times as you want
    print("Good Morning")
def greet():
    print("Good Morning")
def greet():
    print("Good Morning")
greet()
greet()
greet()
# Out:
# Good Morning
# Good Morning
# Good Morning

# %%
def greet():  # you define the statement once you can call as many times as you want
    print("Good Morning")
greet()
greet()
greet()
# Out:
# Good Morning
# Good Morning
# Good Morning

# %%
def greet():  # you define the statement once you can call as many times as you want (without argument)
    print("Good Morning")
    print("Bye")
greet()
greet()
greet()
# Out:
# Good Morning
# Bye
# Good Morning
# Bye
# Good Morning
# Bye

# %%
def add(x,y):    #formal argument This is a function contains argument
    z=x+y
    print(z)
add(5,6)      #actual argument
# Out:
# 11

# %%
def add(x,y):    #formal argument This is a function contains argument
    z=x+y
    print(z)
add(5,6,7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       1 def add(x,y):    #formal argument This is a function contains argument
#       2     z=x+y
#       3     print(z)
# ----> 4 add(5,6,7)
#
# TypeError: add() takes 2 positional arguments but 3 were given

# %%
def add(x,y):    
    z=x+y
    print(z)
add(5,5,7,8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       1 def add(x,y):    #formal argument This is a function contains argument
#       2     z=x+y
#       3     print(z)
# ----> 4 add(5,5,7,8)
#
# TypeError: add() takes 2 positional arguments but 4 were given

# %%
def add(x,y,t):    
    z=x+y
    print(z)
add(5,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       1 def add(x,y,t):
#       2     z=x+y
#       3     print(z)
# ----> 4 add(5,5)
#
# TypeError: add() missing 1 required positional argument: 't'

# %%
def add(x,y):    
    c=x+y
    print(c)     #print function is used so we are not gretting correct datatype
r=add(5,6) 
print(r)
print(type(r))
# Out:
# 11
# None
# <class 'NoneType'>

# %%
def add(x,y):    
    c=x+y
    return(c)   #here return keyword is used to get the correct datatype
r=add(5,6) 
print(r)
print(type(r))
# Out:
# 11
# <class 'int'>

# %%
def greet():
    print("Good Morning")       #this is not a clean code
greet()
def add(x,y):    
    z=x+y
    return(z)
add(5,6)
# Out:
# Good Morning
# 11

# %%
def greet():
    print("Good Morning")       #this is a clean code
def add(x,y):    
    z=x+y
    return(z)
greet()
add(5,6)
# Out:
# Good Morning
# 11

# %%
def greet():
    print("Good Morning")
def add(x,y):
    c=x+y
    print(c)
def diff(x,y):
    c=x-y
    print(c)
greet()
add(5,6)
diff(5,6)
# Out:
# Good Morning
# 11
# -1

# %%
def greet():
    return("Good Morning")
def add(x,y):
    c=x+y
    return(c)
def diff(x,y):
    c=x-y
    return(c)
print(greet())
print(add(5,6))
print(diff(5,6))
# Out:
# Good Morning
# 11
# -1

# %%
def greet():
    print("Good Morning")
def add_diff(x,y):
    c=x+y
    d=x-y
    return(c,d)      # here output is tuple
greet()
add_diff(5,6)
# Out:
# Good Morning
# (11, -1)

# %%
def greet():
    return("Good Morning")
def add_diff(x,y):
    c=x+y
    d=x-y
    return(c,d)      # here output is tuple
r=greet()
r1=add_diff(5,6)
print(r)
print(r1)
print(type(r))
print(type(r1))
# Out:
# Good Morning
# (11, -1)
# <class 'str'>
# <class 'tuple'>

# %%
def greet():
    return("Good Morning")
def add_diff(x,y):
    c=x+y
    d=x-y
    return(c,d)      # here output is tuple
r=greet()
r1,r2=add_diff(5,6)
print(r)
print(r1)
print(r2)
print(type(r))
print(type(r1))
# Out:
# Good Morning
# 11
# -1
# <class 'str'>
# <class 'int'>

# %%
def add_sub(x,y):
    c=x+y
    d=x-y
    return(c,d)
r,r1=add_sub(5,6)
print(r)
print(r1)
# Out:
# 11
# -1

# %%
def add_sub_mult(x,y):
    c=x+y
    d=x-y
    e=x*y
    return(c,d,e)
r,r1,r2=add_sub_mult(5,6)
print(r)
print(r1)
print(r2)
# Out:
# 11
# -1
# 30

# %% [markdown]
# # Actual argument is defined when we call the function
# There are 5 types of Actual arguments:
# 1)Positional arguments
# 2)Keyword Arguments
# 3)Default Arguments
# 4)Variable length Argumnets(Args)
# 5)Keyword + Variable length Arguments(KWARGS)

# %% [markdown]
# # 1)POSITIONAL ARGUMNETS:

# %%
def person(name,age):
    print(name)
    print(age)
person("Sumayya",27)
# Out:
# Sumayya
# 27

# %%
def person(name,age):
    print(name)
    print(age)
person(27,"age")
# Out:
# 27
# age

# %%
def person(name,age):
    print(name)
    print(age)
person("sumayya")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 4
#       1 def person(name,age):
#       2     print(name)
#       3     print(age)
# ----> 4 person("sumayya")
#
# TypeError: person() missing 1 required positional argument: 'age'

# %%
def person(name,age):
    print(name)
    print(age)
person(27)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 4
#       1 def person(name,age):
#       2     print(name)
#       3     print(age)
# ----> 4 person(27)
#
# TypeError: person() missing 1 required positional argument: 'age'

# %%
def person(name,age):
    print(name)
    print(age)
person(27)

# %%
def person(name,age,salary):
    print(name)
    print(age)
person("Sumayya",27)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 4
#       1 def person(name,age,salary):
#       2     print(name)
#       3     print(age)
# ----> 4 person("Sumayya",27)
#
# TypeError: person() missing 1 required positional argument: 'salary'

# %%
def person(name,age):
    print(name)
    print(age+1)
person(27,"age",25)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 4
#       1 def person(name,age):
#       2     print(name)
#       3     print(age+1)
# ----> 4 person(27,"age",25)
#
# TypeError: person() takes 2 positional arguments but 3 were given

# %%
def person(name,age):
    print(name)
    print(age+1)
person("Sumayya",27)
# Out:
# Sumayya
# 28

# %% [markdown]
# # 2)KEYWORD ARGUMENTS

# %%
def person(name,age):
    print(name)
    print(age)
person(name="Sumayya",age=27)
# Out:
# Sumayya
# 27

# %%
def person(name,age,mob):
    print(name)
    print(age)
    print(mob)
person(name="Sumayya",age=27,2345)
# Out:
#   Cell In[77], line 5
#     person(name="Sumayya",age=27,2345)
#                                      ^
# SyntaxError: positional argument follows keyword argument

# %%
def person(name,age,mob):
    print(name)
    print(age)
    print(mob)
person(name="Sumayya",age=27,mob=2345)
# Out:
# Sumayya
# 27
# 2345

# %%
def person(name,age,mob):
    print(name)
    print(age)
    print(mob)
person("Sumayya",27,2345)
# Out:
# Sumayya
# 27
# 2345

# %%
def person(name,age,mob,add):
    print(name)
    print(age)
    print(mob)
person(name="Sumayya",age=27,mob=2345,'hyd')
# Out:
#   Cell In[84], line 5
#     person(name="Sumayya",age=27,mob=2345,'hyd')
#                                                ^
# SyntaxError: positional argument follows keyword argument

# %%
def person(name,age,mob,add):
    print(name)
    print(age)
    print(mob)
    print(add)
person(name="Sumayya",age=27,mob=2345,Add='hyd')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 6
#       2     print(name)
#       3     print(age)
#       4     print(mob)
#       5     print(add)
# ----> 6 person(name="Sumayya",age=27,mob=2345,Add='hyd')
#
# TypeError: person() got an unexpected keyword argument 'Add'. Did you mean 'add'?

# %% [markdown]
# # 3)DEFAULT ARGUMENT

# %%
def person(name,age=18):
    print(name)
    print(age)
person("Sumayya")
# Out:
# Sumayya
# 18

# %%
def person(name,age=18):
    print(name)
    print(age)
person("sumayya",20)
# Out:
# sumayya
# 20
