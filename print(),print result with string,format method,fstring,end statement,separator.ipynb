# %% [markdown]
# # 1)print() (in prompt engineering it is imp)

# %%
5+6
7+7
# Out:
# 14

# %%
print(5+6)
print(7+7)
# Out:
# 11
# 14

# %%
a=15
b=10
print(a)
print(b)
# Out:
# 15
# 10

# %%
print(a,b)
# Out:
# 15 10

# %%
c=30
print(a)
print(b)
print(c) #multiple lines of code ,it takes almost 3kb of memory
print(a,b,c) #code optimization(or)Memory optimization:rather than multiple lines of code ,you write code in single line,it take only 1 kb of memory
# Out:
# 15 10 30

# %%
print(a)
print(35)
print("sumayya")
print(55,"sumayya",65)
# Out:
# 15
# 35
# sumayya
# 55 sumayya 65

# %%
num1=10
num2=20
add=num1+num2
print(add)
# Out:
# 30

# %% [markdown]
# # 2)Print result with string

# %%
num1=20
num2=30
add=num1+num2
print("The addition of num1 and num2 is=",add)
# Out:
# The addition of num1 and num2 is 50

# %% [raw]
# # Q)print this line in python code
#    "My name is python and iam 20 year old from hyderbad city"

# %%
name="python"
age=20
city="hyderbad"
print("My name is",name,"and iam",age,"year old from",city,"city")
# Out:
# My name is python and iam 20 year old from hyderbad city

# %% [markdown]
# # 3)Print function with format method

# %%
num1=20
num2=30
add=num1+num2
print("The addition of {} and {}={}".format(num1,num2,add))
# Out:
# The addition of 20 and 30=50

# %%
num1=50
num2=50
num3=70
add=num1+num2+num3
print("The addition of {} and {} and {}={}".format(num1,num2,num3,add))
# Out:
# The addition of 50 and 50 and 70=170

# %% [markdown]
# # 4)Print function with fstring

# %%
a=10
b=20
c=30
add=a+b+c
print(f"The addition of {a} and {b} and {c} is= {add}")
# Out:
# The addition of 10 and 20 and 30 is= 60

# %% [markdown]
# # 5)Print function with end statement

# %%
print("Sumayya",end=" ")
print("Kounain")
# Out:
# Sumayya Kounain

# %%
print("Sumayya",end="***")
print("Kounain")
# Out:
# Sumayya***Kounain

# %% [markdown]
# # 6)Print function with separator

# %%
print("hi","hello",sep=",")
# Out:
# hi,hello

# %%
print("hi","hello","How are you",sep="***")
# Out:
# hi***hello***How are you
