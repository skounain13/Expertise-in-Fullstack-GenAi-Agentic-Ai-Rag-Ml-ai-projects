# %% [markdown]
# # 1)INTERGER(int)

# %%
i=5
print(i)
# Out:
# 5

# %%
print(type(i))
# Out:
# <class 'int'>

# %%
type(i)
# Out:
# int

# %%
type() #no arguments or parameter is given inside so error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 type() #no arguments or parameter is given inside so error
#
# TypeError: type() takes 1 or 3 arguments

# %%
age=78
age
# Out:
# 78

# %%
print(age)
print(type(age))
print(i)
# Out:
# 78
# <class 'int'>
# 5

# %% [markdown]
# # id means address of memory location

# %%
print(id(i))
print(id(age))
# Out:
# 140705296278776
# 140705296281112

# %%
p=10
q=10
print(p)
print(q)
print(id(p))
print(id(q))
# Out:
# 10
# 10
# 140705296278936
# 140705296278936

# %%
p=p+10
print(p)
# Out:
# 30

# %%
print(id(p))
# Out:
# 140705296279576

# %%
r=p
print(r)
print(id(r))
# Out:
# 30
# 140705296279576

# %% [markdown]
# # 2)Float Datatype(flt)

# %%
f=1.1
print(f)
print(type(f))
# Out:
# 1.1
# <class 'float'>

# %%
f=111.34
print(type(f))
print(id(f))
# Out:
# <class 'float'>
# 1614891798992

# %%
print(i)
print(age)
print(f)
# Out:
# 5
# 78
# 111.34

# %% [markdown]
# # 3)BOOLEAN DATATYPE(bool)

# %%
b=true
b #because t is not in capital
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 b=true #because t is not in capital
#
# NameError: name 'true' is not defined

# %%
b=false
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 b=false
#       2 b
#
# NameError: name 'false' is not defined

# %%
b=True
b
# Out:
# True

# %%
b=False
b
# Out:
# False

# %%
print(type(b))
# Out:
# <class 'bool'>

# %%
print(id(b))
# Out:
# 140705295364640

# %%
True+False #we used operand (True=1 and False=0)
# Out:
# 1

# %%
True*False
# Out:
# 0

# %%
False/True #it takes the quotient as output
# Out:
# 0.0

# %%
True/False #it is infinity so zero divison error
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 True/False #it is infinity so zero divison error
#
# ZeroDivisionError: division by zero

# %%
False//True #max of quotient
# Out:
# 0

# %% [markdown]
# # 4)COMPLEX DATATYPE

# %%
c=5+5j
c
# Out:
# (5+5j)

# %%
print(type(c))
# Out:
# <class 'complex'>

# %%
print(id(c))
# Out:
# 1614893514928

# %%
c=5+5j
d=5+5j
print(c+d)
# Out:
# (10+10j)

# %%
c=13+15j
c
# Out:
# (13+15j)

# %%
c.real
# Out:
# 13.0

# %%
c.imag
# Out:
# 15.0
