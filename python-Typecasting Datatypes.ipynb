# %% [markdown]
# # 1)typecasting different datatypes to int

# %% [markdown]
# # i)float to int

# %%
int(130.65)
# Out:
# 130

# %% [markdown]
# # ii)bool to int

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %% [markdown]
# # iii)complex to int(NOT POSSIBLE)

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %% [markdown]
# # iv)string(no.(possible),text(NOT POSSIBLE)) to int

# %%
int('10')

# %%
int('ten')

# %% [markdown]
# # 2)Type casting different data types to float

# %% [markdown]
# # i)int to float

# %%
float(10)
# Out:
# 10.0

# %% [markdown]
# # ii)bool to float

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %% [markdown]
# # iii)complex to float(NOT POSSIBLE)

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %% [markdown]
# # iv)str(no.(possible),text(not possible)  to float)

# %%
float('10')
# Out:
# 10.0

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %% [markdown]
# # 3)Typecasting Different datatypes to bool

# %% [markdown]
# # i)int to bool

# %%
bool(10)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool()
# Out:
# False

# %%
bool(-3)
# Out:
# True

# %% [markdown]
# # ii)float to bool

# %%
bool(10.3)
# Out:
# True

# %%
bool(0.0)
# Out:
# False

# %% [markdown]
# # iii)complex to bool

# %%
bool(1+2j)
# Out:
# True

# %% [markdown]
# # iv)str(no.,text) to bool

# %%
bool('10')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %% [markdown]
# # 4)Typecasting different datatypes to complex

# %% [markdown]
# # i)int to complex

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10,15)
# Out:
# (10+15j)

# %%
complex(3,4,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 complex(3,4,5)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %% [markdown]
# # ii)float to complex

# %%
complex(10.0)
# Out:
# (10+0j)

# %%
complex(10.15)
# Out:
# (10.15+0j)

# %%
complex()
# Out:
# 0j

# %%
complex(3.5,4.5)
# Out:
# (3.5+4.5j)

# %% [markdown]
# # iii)bool to complex

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %% [markdown]
# # iv)str(no.(possible),text(not possible)) to complex

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('10','20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 complex('10','20')
#
# TypeError: complex() argument 'real' must be a real number, not str

# %%
complex(10,'20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 complex(10,'20')
#
# TypeError: complex() argument 'imag' must be a real number, not str

# %%
complex('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 complex('ten')
#
# ValueError: complex() arg is a malformed string

# %% [markdown]
# # 5)Typecasting datatypes to string

# %% [markdown]
# # i)int to string

# %%
str(10)
# Out:
# '10'

# %%
str()
# Out:
# ''

# %% [markdown]
# # ii)float to string

# %%
str(10.15)
# Out:
# '10.15'

# %%
str(10.00)
# Out:
# '10.0'

# %% [markdown]
# # iii)bool to string

# %%
str(True)
# Out:
# 'True'

# %%
str('False')
# Out:
# 'False'

# %% [markdown]
# # iv)complex to string

# %%
str(10+5j)
# Out:
# '(10+5j)'

# %%
str(0+0j)
# Out:
# '0j'
