# %% [markdown]
# # 1)math:(sqrt,floor,ceil,pow)

# %%
25
# Out:
# 25

# %%
sqrt(25) #unable to get the sqrt so we use math to get
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import math
math.sqrt(25)                                               # i)math with sqrt
# Out:
# 5.0

# %%
math.floor(3.5)                       # ii)math with floor (3.5 lies in btwn (3 and 4) so floor takes least value)
# Out:
# 3

# %%
math.ceil(3.5)                         # iii)math with ceil (3.5 lies in btwn (3 and 4) so ceil takes max value)
# Out:
# 4

# %%
math.floor(4.9)
# Out:
# 4

# %%
math.ceil(4.9)
# Out:
# 5

# %%
math.pow(2,3)                                                # iv) math with pow (2*2*2=8)
# Out:
# 8.0

# %%
m.floor(3.5)                                      # we are unable to write math as m so import function is used
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 m.floor(3.5)
#
# NameError: name 'm' is not defined

# %%
import math as m                               # v) keyword(import and as) are used here to write short from of math
print(m.sqrt(25))
# Out:
# 5.0

# %%
import math as m
print(m.floor(3.4))
# Out:
# 3

# %%
import math as m
print(m.ceil(2.5))
# Out:
# 3

# %%
import math as m
print(m.pow(4,2))
# Out:
# 16.0

# %%
import math as s  # in place of m we can write any letter
print(s.sqrt(16))
print(s.floor(5.6))
print(s.ceil(7.9))
print(s.pow(2,2))
# Out:
# 4.0
# 5
# 8
# 4.0

# %%
from math import sqrt,floor,ceil,pow            # this is called as code optimization: no need to write everytime ,once you declare it is enough
print(sqrt(16))
print(floor(5.6))                                    # from keyword is used here
print(ceil(7.9))
print(pow(2,2))
# Out:
# 4.0
# 5
# 8
# 4.0

# %%
from math import *                # in order to print everything at one time we use (*) that means  print all,it is a inbulid function
print(sqrt(16))
print(floor(5.6))
print(ceil(7.9))
print(pow(2,2))
# Out:
# 4.0
# 5
# 8
# 4.0

# %% [markdown]
# # 2)input()

# %%
x=input()
y=input()         # it is just concatenating two values 2,2=22
z=x+y
print(z)
# Out:
#  2
#  2
# 22

# %%
x=input()
y=input()         # input() it just takes '+' not(-,*,/,//,)
z=x*y
print(z)
# Out:
#  2
#  2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 x=input()
#       2 y=input()         # it is just concatenating two values 2,2=22
# ----> 3 z=x*y
#       4 print(z)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
x=input()     # input() is very useful in everywhere eg:insta,fb,bank account etc...input() always gives a prompt so that user can enter
x
# Out:
#  5
# '5'

# %%
x=input('Enter the number1:')
y=input('Enter the number2:')             # input() always a string, so we need to typecaste it by mentioning before int(input("enter"))
add=x+y
print(add)
# Out:
# Enter the number1: 5
# Enter the number2: 5
# 55

# %%
print(type(x))                  
print(type(y))
# Out:
# <class 'str'>
# <class 'str'>

# %%
x=int(input("Enter the number 1:"))           #typecasting to get sum of the values 
y=int(input("Enter the number 2:"))
print(x+y)
# Out:
# Enter the number 1: 5
# Enter the number 2: 5
# 10

# %%
x=input('user_name')
y=input('password')
z=x+y
print(z)
# Out:
# user_name Sumayya_123
# password sumayya123
# Sumayya_123sumayya123

# %%
x=int(input("Enter the aadhar number:")[8:])
print(x)
# Out:
# Enter the aadhar number: 123456789562
# 9562

# %%
x="10"
x
# Out:
# '10'

# %%
type(x)
# Out:
# str

# %%
x=int("10")
type(x)
# Out:
# int

# %%
x=float("10")
x
# Out:
# 10.0

# %% [markdown]
# # 3)input() with string and indexing the string

# %%
str=input('Enter your name')
str
# Out:
# Enter your name Sumayya
# 'Sumayya'

# %%
str=input('Enter your name')[0:2]
str
# Out:
# Enter your name Sumayya
# 'Su'

# %% [markdown]
# # 4) Eval

# %%
result=input("Enter the expression")     # here we are unable to solve the expression
result
# Out:
# Enter the expression 5-5-2+8
# '5-5-2+8'

# %%
result=eval(input("Enter the expression"))      # with the help of eval we solve the exp
result
# Out:
# Enter the expression 5-5-2+8
# 6
